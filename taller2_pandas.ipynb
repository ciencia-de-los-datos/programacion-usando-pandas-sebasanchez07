# %%
import pandas as pd

tbl0 = pd.read_csv("tbl0.tsv", sep="\t")
tbl1 = pd.read_csv("tbl1.tsv", sep="\t")
tbl2 = pd.read_csv("tbl2.tsv", sep="\t")

# %% [markdown]
# # Pregunta 1

# %%
tbl0.shape[0]
# Out:
# 40

# %%
def pregunta_01():

    return tbl0.shape[0]

# %%
pregunta_01()
# Out:
# 40

# %% [markdown]
# # Pregunta 3

# %%
tbl0["_c1"].value_counts()
# Out:
# E    14
# A     8
# B     7
# D     6
# C     5
# Name: _c1, dtype: int64

# %%
tbl0[["_c1", "_c2"]].groupby("_c1").mean()
# Out:
#           _c2
# _c1
# A    4.625000
# B    5.142857
# C    5.400000
# D    3.833333
# E    4.785714

# %%
# Out:
#    _c1  _c2
# 0    E    1
# 1    A    2
# 2    B    5
# 3    A    3
# 4    C    6
# 5    A    7
# 6    A    9
# 7    B    1
# 8    E    2
# 9    B    3
# 10   C    7
# 11   C    5
# 12   D    3
# 13   E    8
# 14   B    9
# 15   D    1
# 16   E    3
# 17   D    5
# 18   E    8
# 19   E    9
# 20   E    7
# 21   E    3
# 22   D    5
# 23   A    1
# 24   E    4
# 25   E    6
# 26   A    8
# 27   E    5
# 28   A    6
# 29   C    0
# 30   A    1
# 31   D    2
# 32   E    5
# 33   B    4
# 34   B    6
# 35   D    7
# 36   B    8
# 37   C    9
# 38   E    1
# 39   E    5

# %%
tbl0[["_c1", "_c2"]].groupby("_c1").max()
# Out:
#      _c2
# _c1
# A      9
# B      9
# C      9
# D      7
# E      9

# %%
tbl1.columns
# Out:
# Index(['_c0', '_c4'], dtype='object')

# %%
[tbl1["_c4"].unique()]
# Out:
# [array(['b', 'g', 'f', 'a', 'c', 'e', 'd'], dtype=object)]

# %%
[i.upper() for i in tbl1["_c4"]]
# Out:
# ['B',
#  'G',
#  'F',
#  'A',
#  'F',
#  'C',
#  'F',
#  'E',
#  'A',
#  'C',
#  'A',
#  'B',
#  'F',
#  'G',
#  'D',
#  'A',
#  'C',
#  'D',
#  'G',
#  'D',
#  'A',
#  'B',
#  'A',
#  'D',
#  'E',
#  'A',
#  'F',
#  'D',
#  'B',
#  'G',
#  'F',
#  'D',
#  'C',
#  'F',
#  'B',
#  'D',
#  'E',
#  'A',
#  'C',
#  'G',
#  'E',
#  'F',
#  'B',
#  'C',
#  'F',
#  'D',
#  'B',
#  'F',
#  'E',
#  'E',
#  'B',
#  'F',
#  'G',
#  'A',
#  'E',
#  'C',
#  'F',
#  'A',
#  'E',
#  'A',
#  'E',
#  'F',
#  'C',
#  'B',
#  'G',
#  'C',
#  'F',
#  'A',
#  'F',
#  'A',
#  'D',
#  'C',
#  'D',
#  'E',
#  'D',
#  'C',
#  'A',
#  'E',
#  'F',
#  'C',
#  'A',
#  'G',
#  'F',
#  'E',
#  'F',
#  'C',
#  'A',
#  'G',
#  'B',
#  'F',
#  'B',
#  'F',
#  'A',
#  'C',
#  'B',
#  'F',
#  'C',
#  'F',
#  'A',
#  'E',
#  'A',
#  'F',
#  'C',
#  'A',
#  'C',
#  'A',
#  'E',
#  'F',
#  'E',
#  'D',
#  'F',
#  'A',
#  'D']

# %%
from pandas import unique


unique([i.upper() for i in tbl1["_c4"]])
# Out:
# array(['B', 'G', 'F', 'A', 'C', 'E', 'D'], dtype=object)

# %%
import numpy as np
list(np.sort(unique([i.upper() for i in tbl1["_c4"]])))
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
np.array([1, 2, 3]) + 10
# Out:
# array([11, 12, 13])

# %% [markdown]
# # Pregunta 7

# %%
tbl0.columns
# Out:
# Index(['_c0', '_c1', '_c2', '_c3'], dtype='object')

# %%
tbl0[["_c1", "_c2"]]
# Out:
#    _c1  _c2
# 0    E    1
# 1    A    2
# 2    B    5
# 3    A    3
# 4    C    6
# 5    A    7
# 6    A    9
# 7    B    1
# 8    E    2
# 9    B    3
# 10   C    7
# 11   C    5
# 12   D    3
# 13   E    8
# 14   B    9
# 15   D    1
# 16   E    3
# 17   D    5
# 18   E    8
# 19   E    9
# 20   E    7
# 21   E    3
# 22   D    5
# 23   A    1
# 24   E    4
# 25   E    6
# 26   A    8
# 27   E    5
# 28   A    6
# 29   C    0
# 30   A    1
# 31   D    2
# 32   E    5
# 33   B    4
# 34   B    6
# 35   D    7
# 36   B    8
# 37   C    9
# 38   E    1
# 39   E    5

# %%
tbl0[["_c1", "_c2"]].groupby("_c1").sum()
# Out:
#      _c2
# _c1
# A     37
# B     36
# C     27
# D     23
# E     67
